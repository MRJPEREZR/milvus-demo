# %% [markdown]
# # Create collection

# %%
from pymilvus import MilvusClient
client = MilvusClient("milvus_demo.db")
client.create_collection(
  collection_name="demo_collection",
  dimension=5
)

# %% [markdown]
# # Insert Data

# %%
client.insert(
  collection_name="demo_collection",
  data=[
    {"id": 0, "vector": [0.1, 0.2, 0.3, 0.2, 0.1], "text": "AI was proposed in 1956.", "subject": "history"},
    {"id": 1, "vector": [0.1, 0.2, 0.3, 0.2, 0.1], "text": "Alan Turing was born in London.", "subject": "history"},
    {"id": 2, "vector": [0.1, 0.2, 0.3, 0.2, 0.1], "text": "Computational synthesis with AI algorithms predicts molecular properties.", "subject": "biology"},
  ]
)
# Out:
# {'insert_count': 3, 'ids': [0, 1, 2], 'cost': 0}

# %% [markdown]
# # Search

# %%
client.search(
  collection_name="demo_collection",
  data=[[0.1, 0.2, 0.3, 0.2, 0.1]],
  filter="subject == 'history'",
  limit=2,
  output_fields=["text", "subject"],
)
# Out:
# data: [[{'id': 0, 'distance': 0.9999999403953552, 'entity': {'text': 'AI was proposed in 1956.', 'subject': 'history'}}, {'id': 1, 'distance': 0.9999999403953552, 'entity': {'text': 'Alan Turing was born in London.', 'subject': 'history'}}]]

# %% [markdown]
# # Delete data

# %%
client.delete(
  collection_name="demo_collection",
  ids=[0,2]
)
# Out:
# [0, 2]
